# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs

# %%
Datos=make_blobs(1000,2,centers=2,cluster_std=[2,4],random_state=2610,)

# %%
import matplotlib.pyplot as plt

plt.scatter(Datos[0][:,0],Datos[0][:,1],c=Datos[1])
plt.show()

# %%
import pandas as pd
Dataset=pd.DataFrame(Datos[0],columns=['x','y'])
Dataset['output']=Datos[1]
Dataset
# Out:
#              x         y  output
# 0    -1.697490 -9.277352       0
# 1   -11.667034  2.628434       1
# 2    -6.547549 -7.702224       0
# 3    -7.524013  4.411830       1
# 4    -6.719957  1.089161       1
# ..         ...       ...     ...
# 995  -0.617624 -5.623399       0
# 996  -6.284152  0.416071       1
# 997  -2.513713 -9.762308       0
# 998  -3.611571 -9.210472       0
# 999  -5.086745 -6.960507       0
#
# [1000 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
## Instancio
logistic_model=LogisticRegression()
# Ajusto
logistic_model.fit(Dataset[['x','y']],Dataset['output'])
# Predecir
y_pred=logistic_model.predict(Dataset[['x','y']])

print(classification_report(y_true=Dataset['output'],y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       500
#            1       0.99      0.99      0.99       500
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000

# %%
print(logistic_model.coef_)
print(logistic_model.intercept_)
# Out:
# [[-0.96171399  1.52122688]]
# [0.31953269]

# %%
-0.96

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-15,5,1000)
y=(0.9617/1.52122)*x-0.31953269

todos_lo_puntos=[]

for x_pun in np.linspace(-15,5,100):
    for y_pun in np.linspace(-15,5,100):
        todos_lo_puntos.append([x_pun,y_pun])
todos_lo_puntos=np.array(todos_lo_puntos)
y_pred_tod= logistic_model.predict(todos_lo_puntos)

plt.scatter(Datos[0][:,0],Datos[0][:,1],c=Datos[1])
plt.scatter(todos_lo_puntos[:,0],todos_lo_puntos[:,1],c=y_pred_tod,alpha=0.1)
plt.plot(x,y)
plt.show()
# Out:
# c:\Users\SALA\anaconda3\envs\ml2024\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeClassifier

model_arbol=DecisionTreeClassifier(max_depth=2)

# Ajusto
model_arbol.fit(Dataset[['x','y']],Dataset['output'])
# Predecir
y_pred=model_arbol.predict(Dataset[['x','y']])

print(classification_report(y_true=Dataset['output'],y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       500
#            1       0.99      0.99      0.99       500
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000

# %%
import matplotlib.pyplot as plt
import numpy as np

todos_lo_puntos=[]

for x_pun in np.linspace(-15,5,100):
    for y_pun in np.linspace(-15,5,100):
        todos_lo_puntos.append([x_pun,y_pun])
todos_lo_puntos=np.array(todos_lo_puntos)
y_pred_tod= model_arbol.predict(todos_lo_puntos)

plt.scatter(Datos[0][:,0],Datos[0][:,1],c=Datos[1])
plt.scatter(todos_lo_puntos[:,0],todos_lo_puntos[:,1],c=y_pred_tod,alpha=0.1)
plt.show()
# Out:
# c:\Users\SALA\anaconda3\envs\ml2024\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.neighbors import KNeighborsClassifier

modelo_knn=KNeighborsClassifier(n_neighbors=9)

# Ajusto
modelo_knn.fit(Dataset[['x','y']],Dataset['output'])
# Predecir
y_pred=modelo_knn.predict(Dataset[['x','y']])

print(classification_report(y_true=Dataset['output'],y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       500
#            1       0.99      0.99      0.99       500
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000

# %%
import matplotlib.pyplot as plt
import numpy as np

todos_lo_puntos=[]

for x_pun in np.linspace(-15,5,100):
    for y_pun in np.linspace(-15,5,100):
        todos_lo_puntos.append([x_pun,y_pun])
todos_lo_puntos=np.array(todos_lo_puntos)
y_pred_tod= modelo_knn.predict(todos_lo_puntos)

plt.scatter(Datos[0][:,0],Datos[0][:,1],c=Datos[1])
plt.scatter(todos_lo_puntos[:,0],todos_lo_puntos[:,1],c=y_pred_tod,alpha=0.1)
plt.show()
# Out:
# c:\Users\SALA\anaconda3\envs\ml2024\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestClassifier

modelo_bosque=RandomForestClassifier(max_depth=5,n_estimators=100,verbose=1)

# Ajusto
modelo_bosque.fit(Dataset[['x','y']],Dataset['output'])
# Predecir
y_pred=modelo_bosque.predict(Dataset[['x','y']])

print(classification_report(y_true=Dataset['output'],y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       500
#            1       1.00      1.00      1.00       500
#
#     accuracy                           1.00      1000
#    macro avg       1.00      1.00      1.00      1000
# weighted avg       1.00      1.00      1.00      1000
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s

# %%
import matplotlib.pyplot as plt
import numpy as np

todos_lo_puntos=[]

for x_pun in np.linspace(-15,5,100):
    for y_pun in np.linspace(-15,5,100):
        todos_lo_puntos.append([x_pun,y_pun])
todos_lo_puntos=np.array(todos_lo_puntos)
y_pred_tod= modelo_bosque.predict(todos_lo_puntos)

plt.scatter(Datos[0][:,0],Datos[0][:,1],c=Datos[1])
plt.scatter(todos_lo_puntos[:,0],todos_lo_puntos[:,1],c=y_pred_tod,alpha=0.1)
plt.show()
# Out:
# c:\Users\SALA\anaconda3\envs\ml2024\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s

# %%
from sklearn.svm import SVC

modelo_SVC=SVC(kernel='poly',degree=2)

# Ajusto
modelo_SVC.fit(Dataset[['x','y']],Dataset['output'])
# Predecir
y_pred=modelo_SVC.predict(Dataset[['x','y']])

print(classification_report(y_true=Dataset['output'],y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       500
#            1       0.99      0.99      0.99       500
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000

# %%
import matplotlib.pyplot as plt
import numpy as np

todos_lo_puntos=[]

for x_pun in np.linspace(-15,5,100):
    for y_pun in np.linspace(-15,5,100):
        todos_lo_puntos.append([x_pun,y_pun])
todos_lo_puntos=np.array(todos_lo_puntos)
y_pred_tod= modelo_SVC.predict(todos_lo_puntos)

plt.scatter(Datos[0][:,0],Datos[0][:,1],c=Datos[1])
plt.scatter(todos_lo_puntos[:,0],todos_lo_puntos[:,1],c=y_pred_tod,alpha=0.1)
plt.show()
# Out:
# c:\Users\SALA\anaconda3\envs\ml2024\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
